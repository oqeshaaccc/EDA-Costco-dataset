# %% [markdown]
# <a href="https://colab.research.google.com/github/oqeshaaccc/EDA-Costco-dataset/blob/main/EDA_costco_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read the data
# - data set is costco_warehouses.json

# %%
import pandas as pd
df = pd.read_json("costco_warehouses.json")
df.head()
# Out:
#    stlocID  displayName  identifier           phone fax  \
# 0        1            1           1  (206) 622-3136
# 1        2            2           2  (503) 252-2243
# 2        6            6           6  (206) 575-9191
# 3        8            8           8  (425) 827-1693
# 4        9            9           9  (503) 644-7615
#
#                 address1      city state country     zipCode  ...  \
# 0         4401 4TH AVE S   SEATTLE    WA      US  98134-2389  ...
# 1      4849 NE 138TH AVE  PORTLAND    OR      US  97230-3401  ...
# 2  400 COSTCO DR STE 150   TUKWILA    WA      US  98188-4808  ...
# 3      8629 120TH AVE NE  KIRKLAND    WA      US  98033-5865  ...
# 4    15901 SW JENKINS RD     ALOHA    OR      US  97006-5098  ...
#
#                                      tireCenterHours  \
# 0  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 1  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 2  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 3  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 4  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
#
#                                            gasPrices  \
# 0  {'warehouseid': '1', 'regular': '2.799', 'prem...
# 1  {'warehouseid': '2', 'diesel': '2.899', 'regul...
# 2  {'warehouseid': '6', 'diesel': '2.959', 'regul...
# 3  {'warehouseid': '8', 'regular': '2.739', 'prem...
# 4  {'warehouseid': '9', 'regular': '2.759', 'prem...
#
#                                         coreServices  \
# 0  [{'name': 'Gas Station', 'localizedName': 'Gas...
# 1  [{'name': 'Gas Station', 'localizedName': 'Gas...
# 2  [{'name': 'Gas Station', 'localizedName': 'Gas...
# 3  [{'name': 'Gas Station', 'localizedName': 'Gas...
# 4  [{'name': 'Gas Station', 'localizedName': 'Gas...
#
#                                 specialtyDepartments  locationName  \
# 0  [{'name': 'Auto Buying Program', 'localizedNam...       Seattle
# 1  [{'name': 'ATM', 'localizedName': 'ATM', 'phon...      Portland
# 2  [{'name': 'Auto Buying Program', 'localizedNam...       Tukwila
# 3  [{'name': 'Auto Buying Program', 'localizedNam...      Kirkland
# 4  [{'name': 'Auto Buying Program', 'localizedNam...         Aloha
#
#    isShipToWarehouse  isWarehousePickup  enableShipToHome  \
# 0               True               True             False
# 1               True               True             False
# 2               True               True             False
# 3               True               True             False
# 4               True               True             False
#
#    isBusinessWarehouse  closeDate
# 0                False        NaN
# 1                False        NaN
# 2                False        NaN
# 3                False        NaN
# 4                False        NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# Some Understanding of the dataset

# %%
df.shape
# Out:
# (782, 41)

# %%
df.columns
# Out:
# Index(['stlocID', 'displayName', 'identifier', 'phone', 'fax', 'address1',
#        'city', 'state', 'country', 'zipCode', 'manager', 'openDate',
#        'tiresDepartmentPhone', 'distance', 'latitude', 'longitude',
#        'parentGeoNodeID', 'active', 'languageID', 'hasGasDepartment',
#        'hasTiresDepartment', 'hasFoodDepartment', 'hasHearingDepartment',
#        'hasPharmacyDepartment', 'hasOpticalDepartment',
#        'hasBusinessDepartment', 'hasPhotoCenterDepartment', 'warehouseHours',
#        'pharmacyHours', 'upcomingHolidays', 'gasStationHours',
#        'tireCenterHours', 'gasPrices', 'coreServices', 'specialtyDepartments',
#        'locationName', 'isShipToWarehouse', 'isWarehousePickup',
#        'enableShipToHome', 'isBusinessWarehouse', 'closeDate'],
#       dtype='object')

# %%
df.dtypes
# Out:
# stlocID                       int64
# displayName                   int64
# identifier                    int64
# phone                        object
# fax                          object
# address1                     object
# city                         object
# state                        object
# country                      object
# zipCode                      object
# manager                      object
# openDate                     object
# tiresDepartmentPhone         object
# distance                    float64
# latitude                    float64
# longitude                   float64
# parentGeoNodeID               int64
# active                        int64
# languageID                    int64
# hasGasDepartment               bool
# hasTiresDepartment             bool
# hasFoodDepartment              bool
# hasHearingDepartment           bool
# hasPharmacyDepartment          bool
# hasOpticalDepartment           bool
# hasBusinessDepartment          bool
# hasPhotoCenterDepartment       bool
# warehouseHours               object
# pharmacyHours                object
# upcomingHolidays             object
# gasStationHours              object
# tireCenterHours              object
# gasPrices                    object
# coreServices                 object
# specialtyDepartments         object
# locationName                 object
# isShipToWarehouse              bool
# isWarehousePickup              bool
# enableShipToHome               bool
# isBusinessWarehouse            bool
# closeDate                    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# stlocID                       0
# displayName                   0
# identifier                    0
# phone                         0
# fax                           0
# address1                      0
# city                          0
# state                         0
# country                       0
# zipCode                       0
# manager                       0
# openDate                      0
# tiresDepartmentPhone          0
# distance                      0
# latitude                      0
# longitude                     0
# parentGeoNodeID               0
# active                        0
# languageID                    0
# hasGasDepartment              0
# hasTiresDepartment            0
# hasFoodDepartment             0
# hasHearingDepartment          0
# hasPharmacyDepartment         0
# hasOpticalDepartment          0
# hasBusinessDepartment         0
# hasPhotoCenterDepartment      0
# warehouseHours                0
# pharmacyHours                 0
# upcomingHolidays              0
# gasStationHours               0
# tireCenterHours               0
# gasPrices                   203
# coreServices                  0
# specialtyDepartments          0
# locationName                  0
# isShipToWarehouse             0
# isWarehousePickup             0
# enableShipToHome              0
# isBusinessWarehouse           0
# closeDate                   781
# dtype: int64

# %% [markdown]
# # drop closeDate column

# %%
df.drop('closeDate', axis=1, inplace = True)
df.head()
# Out:
#    stlocID  displayName  identifier           phone fax  \
# 0        1            1           1  (206) 622-3136
# 1        2            2           2  (503) 252-2243
# 2        6            6           6  (206) 575-9191
# 3        8            8           8  (425) 827-1693
# 4        9            9           9  (503) 644-7615
#
#                 address1      city state country     zipCode  ...  \
# 0         4401 4TH AVE S   SEATTLE    WA      US  98134-2389  ...
# 1      4849 NE 138TH AVE  PORTLAND    OR      US  97230-3401  ...
# 2  400 COSTCO DR STE 150   TUKWILA    WA      US  98188-4808  ...
# 3      8629 120TH AVE NE  KIRKLAND    WA      US  98033-5865  ...
# 4    15901 SW JENKINS RD     ALOHA    OR      US  97006-5098  ...
#
#                                      gasStationHours  \
# 0  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 1  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 2  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 3  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 4  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
#
#                                      tireCenterHours  \
# 0  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 1  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 2  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 3  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 4  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
#
#                                            gasPrices  \
# 0  {'warehouseid': '1', 'regular': '2.799', 'prem...
# 1  {'warehouseid': '2', 'diesel': '2.899', 'regul...
# 2  {'warehouseid': '6', 'diesel': '2.959', 'regul...
# 3  {'warehouseid': '8', 'regular': '2.739', 'prem...
# 4  {'warehouseid': '9', 'regular': '2.759', 'prem...
#
#                                         coreServices  \
# 0  [{'name': 'Gas Station', 'localizedName': 'Gas...
# 1  [{'name': 'Gas Station', 'localizedName': 'Gas...
# 2  [{'name': 'Gas Station', 'localizedName': 'Gas...
# 3  [{'name': 'Gas Station', 'localizedName': 'Gas...
# 4  [{'name': 'Gas Station', 'localizedName': 'Gas...
#
#                                 specialtyDepartments  locationName  \
# 0  [{'name': 'Auto Buying Program', 'localizedNam...       Seattle
# 1  [{'name': 'ATM', 'localizedName': 'ATM', 'phon...      Portland
# 2  [{'name': 'Auto Buying Program', 'localizedNam...       Tukwila
# 3  [{'name': 'Auto Buying Program', 'localizedNam...      Kirkland
# 4  [{'name': 'Auto Buying Program', 'localizedNam...         Aloha
#
#    isShipToWarehouse  isWarehousePickup  enableShipToHome  isBusinessWarehouse
# 0               True               True             False                False
# 1               True               True             False                False
# 2               True               True             False                False
# 3               True               True             False                False
# 4               True               True             False                False
#
# [5 rows x 40 columns]

# %% [markdown]
# # How many Costco store in each country

# %%
df['country'].value_counts()
# Out:
# US    543
# CA     99
# MX     39
# UK     29
# JP     26
# KO     16
# TW     13
# AU     12
# ES      2
# IS      1
# FR      1
# CH      1
# Name: country, dtype: int64

# %%
df.groupby(['country','state']).count()
# Out:
#                          stlocID  displayName  identifier  phone  fax  \
# country state
# AU                             6            6           6      6    6
#         ACT                    1            1           1      1    1
#         New South Wales        2            2           2      2    2
#         Queensland             1            1           1      1    1
#         Victoria               2            2           2      2    2
# ...                          ...          ...         ...    ...  ...
# US      UT                    11           11          11     11   11
#         VA                    17           17          17     17   17
#         VT                     1            1           1      1    1
#         WA                    32           32          32     32   32
#         WI                     9            9           9      9    9
#
#                          address1  city  zipCode  manager  openDate  ...  \
# country state                                                        ...
# AU                              6     6        6        6         6  ...
#         ACT                     1     1        1        1         1  ...
#         New South Wales         2     2        2        2         2  ...
#         Queensland              1     1        1        1         1  ...
#         Victoria                2     2        2        2         2  ...
# ...                           ...   ...      ...      ...       ...  ...
# US      UT                     11    11       11       11        11  ...
#         VA                     17    17       17       17        17  ...
#         VT                      1     1        1        1         1  ...
#         WA                     32    32       32       32        32  ...
#         WI                      9     9        9        9         9  ...
#
#                          gasStationHours  tireCenterHours  gasPrices  \
# country state
# AU                                     6                6          2
#         ACT                            1                1          0
#         New South Wales                2                2          1
#         Queensland                     1                1          0
#         Victoria                       2                2          0
# ...                                  ...              ...        ...
# US      UT                            11               11         11
#         VA                            17               17         14
#         VT                             1                1          0
#         WA                            32               32         31
#         WI                             9                9          9
#
#                          coreServices  specialtyDepartments  locationName  \
# country state
# AU                                  6                     6             6
#         ACT                         1                     1             1
#         New South Wales             2                     2             2
#         Queensland                  1                     1             1
#         Victoria                    2                     2             2
# ...                               ...                   ...           ...
# US      UT                         11                    11            11
#         VA                         17                    17            17
#         VT                          1                     1             1
#         WA                         32                    32            32
#         WI                          9                     9             9
#
#                          isShipToWarehouse  isWarehousePickup  \
# country state
# AU                                       6                  6
#         ACT                              1                  1
#         New South Wales                  2                  2
#         Queensland                       1                  1
#         Victoria                         2                  2
# ...                                    ...                ...
# US      UT                              11                 11
#         VA                              17                 17
#         VT                               1                  1
#         WA                              32                 32
#         WI                               9                  9
#
#                          enableShipToHome  isBusinessWarehouse
# country state
# AU                                      6                    6
#         ACT                             1                    1
#         New South Wales                 2                    2
#         Queensland                      1                    1
#         Victoria                        2                    2
# ...                                   ...                  ...
# US      UT                             11                   11
#         VA                             17                   17
#         VT                              1                    1
#         WA                             32                   32
#         WI                              9                    9
#
# [116 rows x 38 columns]

# %% [markdown]
# # Exploring Costco stores in Canada

# %%
df_CA = df[df['country'] == 'CA']
df_CA.head()
# Out:
#     stlocID  displayName  identifier           phone fax  \
# 16       51           51          51  (604) 420-2668
# 17       54           54          54  (604) 270-3647
# 18       55           55          55  (604) 596-7435
# 19       56           56          56  (403) 299-1610
# 20       57           57          57  (204) 788-4415
#
#                  address1      city state country  zipCode  ...  \
# 16      3550 BRIGHTON AVE   BURNABY    BC      CA  V5A 4W3  ...
# 17     9151 BRIDGEPORT RD  RICHMOND    BC      CA  V6X 3L9  ...
# 18  7423 KING GEORGE BLVD    SURREY    BC      CA  V3W 5A8  ...
# 19          2853 32 ST NE   CALGARY    AB      CA  T1Y 6T7  ...
# 20       1315 ST JAMES ST  WINNIPEG    MB      CA  R3H 0K9  ...
#
#    gasStationHours                                    tireCenterHours  \
# 16              []  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 17              []  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 18              []  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 19              []  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 20              []  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
#
#    gasPrices                                       coreServices  \
# 16       NaN  [{'name': 'Food Court', 'localizedName': 'Food...
# 17       NaN  [{'name': 'Food Court', 'localizedName': 'Food...
# 18       NaN  [{'name': 'Food Court', 'localizedName': 'Food...
# 19       NaN  [{'name': 'Food Court', 'localizedName': 'Food...
# 20       NaN  [{'name': 'Food Court', 'localizedName': 'Food...
#
#                                  specialtyDepartments  locationName  \
# 16  [{'name': '*General Information', 'localizedNa...       Burnaby
# 17  [{'name': '*General Information', 'localizedNa...   Richmond BC
# 18  [{'name': '*General Information', 'localizedNa...        Surrey
# 19  [{'name': '*General Information', 'localizedNa...     N Calgary
# 20  [{'name': '*General Information', 'localizedNa...    W Winnipeg
#
#     isShipToWarehouse  isWarehousePickup  enableShipToHome  \
# 16               True               True             False
# 17               True               True             False
# 18               True               True             False
# 19               True               True             False
# 20               True               True             False
#
#     isBusinessWarehouse
# 16                False
# 17                False
# 18                False
# 19                False
# 20                False
#
# [5 rows x 40 columns]

# %% [markdown]
# # How many Costco store in each Province

# %%
df_CA['state'].value_counts()
# Out:
# ON    35
# QC    21
# AB    17
# BC    14
# MB     3
# SK     3
# NB     3
# NS     2
# NL     1
# Name: state, dtype: int64

# %%
#!pip install pywaffle

from pywaffle import Waffle
import matplotlib.pyplot as plt


# Data
states_df = df_CA['state']
value = states_df.value_counts()

value_dict = value.to_dict() 
#store each state  and its count in a dictionary as this will help with the labels and legend for the waffle chart


# Waffle chart
plt.figure(
    FigureClass = Waffle,
    rows = 10,
    values = value,
    title = {'label':'Costco around the Canadian Provinces Waffle Chart',
             'loc': 'left'}, labels=[f"{k} ({int(v / sum(value_dict.values()) * 100)}%)" for k, v in value_dict.items()],
    legend={
        'loc': 'lower left',
        'bbox_to_anchor': (0, -0.4),
        'ncol': len(states_df),
        'framealpha': 0,
        'fontsize': 12
    }), 


plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)
# <Waffle size 432x288 with 1 Axes>

# %% [markdown]
# # How many pick up locations are there

# %%
df_CA.groupby(["isWarehousePickup"]).count()
# Out:
#                    stlocID  displayName  identifier  phone  fax  address1  \
# isWarehousePickup
# False                    1            1           1      1    1         1
# True                    98           98          98     98   98        98
#
#                    city  state  country  zipCode  ...  upcomingHolidays  \
# isWarehousePickup                                 ...
# False                 1      1        1        1  ...                 1
# True                 98     98       98       98  ...                98
#
#                    gasStationHours  tireCenterHours  gasPrices  coreServices  \
# isWarehousePickup
# False                            1                1          0             1
# True                            98               98         65            98
#
#                    specialtyDepartments  locationName  isShipToWarehouse  \
# isWarehousePickup
# False                                 1             1                  1
# True                                 98            98                 98
#
#                    enableShipToHome  isBusinessWarehouse
# isWarehousePickup
# False                             1                    1
# True                             98                   98
#
# [2 rows x 39 columns]

# %% [markdown]
# # Where is this one store that doesn't have pick up

# %%
df_CA_No_PickUp = df_CA[df_CA["isWarehousePickup"] == False]
df_CA_No_PickUp
# Out:
#      stlocID  displayName  identifier           phone fax       address1  \
# 314      595          595         595  (647) 484-5840      50 THERMOS RD
#
#             city state country  zipCode  ... gasStationHours tireCenterHours  \
# 314  SCARBOROUGH    ON      CA  M1L 0E6  ...              []              []
#
#     gasPrices  coreServices  \
# 314       NaN            []
#
#                                   specialtyDepartments  \
# 314  [{'name': 'Auto Buying Program', 'localizedNam...
#
#                     locationName  isShipToWarehouse  isWarehousePickup  \
# 314  Scarborough Business Center               True              False
#
#      enableShipToHome  isBusinessWarehouse
# 314             False                 True
#
# [1 rows x 40 columns]

# %% [markdown]
# # How many enableShipToHome Costco Stores are there

# %%
df_CA.groupby(["enableShipToHome"]).count()
# Out:
#                   stlocID  displayName  identifier  phone  fax  address1  \
# enableShipToHome
# False                  99           99          99     99   99        99
#
#                   city  state  country  zipCode  ...  upcomingHolidays  \
# enableShipToHome                                 ...
# False               99     99       99       99  ...                99
#
#                   gasStationHours  tireCenterHours  gasPrices  coreServices  \
# enableShipToHome
# False                          99               99         65            99
#
#                   specialtyDepartments  locationName  isShipToWarehouse  \
# enableShipToHome
# False                               99            99                 99
#
#                   isWarehousePickup  isBusinessWarehouse
# enableShipToHome
# False                            99                   99
#
# [1 rows x 39 columns]

# %% [markdown]
# *# Seems like All the costco stores in Canada do not have enableShipToHome feature*

# %% [markdown]
# # View the Canada costco data again for further analysis

# %%
df_CA.head()
# Out:
#     stlocID  displayName  identifier           phone fax  \
# 16       51           51          51  (604) 420-2668
# 17       54           54          54  (604) 270-3647
# 18       55           55          55  (604) 596-7435
# 19       56           56          56  (403) 299-1610
# 20       57           57          57  (204) 788-4415
#
#                  address1      city state country  zipCode  ...  \
# 16      3550 BRIGHTON AVE   BURNABY    BC      CA  V5A 4W3  ...
# 17     9151 BRIDGEPORT RD  RICHMOND    BC      CA  V6X 3L9  ...
# 18  7423 KING GEORGE BLVD    SURREY    BC      CA  V3W 5A8  ...
# 19          2853 32 ST NE   CALGARY    AB      CA  T1Y 6T7  ...
# 20       1315 ST JAMES ST  WINNIPEG    MB      CA  R3H 0K9  ...
#
#    gasStationHours                                    tireCenterHours  \
# 16              []  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 17              []  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 18              []  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 19              []  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 20              []  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
#
#    gasPrices                                       coreServices  \
# 16       NaN  [{'name': 'Food Court', 'localizedName': 'Food...
# 17       NaN  [{'name': 'Food Court', 'localizedName': 'Food...
# 18       NaN  [{'name': 'Food Court', 'localizedName': 'Food...
# 19       NaN  [{'name': 'Food Court', 'localizedName': 'Food...
# 20       NaN  [{'name': 'Food Court', 'localizedName': 'Food...
#
#                                  specialtyDepartments  locationName  \
# 16  [{'name': '*General Information', 'localizedNa...       Burnaby
# 17  [{'name': '*General Information', 'localizedNa...   Richmond BC
# 18  [{'name': '*General Information', 'localizedNa...        Surrey
# 19  [{'name': '*General Information', 'localizedNa...     N Calgary
# 20  [{'name': '*General Information', 'localizedNa...    W Winnipeg
#
#     isShipToWarehouse  isWarehousePickup  enableShipToHome  \
# 16               True               True             False
# 17               True               True             False
# 18               True               True             False
# 19               True               True             False
# 20               True               True             False
#
#     isBusinessWarehouse
# 16                False
# 17                False
# 18                False
# 19                False
# 20                False
#
# [5 rows x 40 columns]

# %%
df_CA.columns
# Out:
# Index(['stlocID', 'displayName', 'identifier', 'phone', 'fax', 'address1',
#        'city', 'state', 'country', 'zipCode', 'manager', 'openDate',
#        'tiresDepartmentPhone', 'distance', 'latitude', 'longitude',
#        'parentGeoNodeID', 'active', 'languageID', 'hasGasDepartment',
#        'hasTiresDepartment', 'hasFoodDepartment', 'hasHearingDepartment',
#        'hasPharmacyDepartment', 'hasOpticalDepartment',
#        'hasBusinessDepartment', 'hasPhotoCenterDepartment', 'warehouseHours',
#        'pharmacyHours', 'upcomingHolidays', 'gasStationHours',
#        'tireCenterHours', 'gasPrices', 'coreServices', 'specialtyDepartments',
#        'locationName', 'isShipToWarehouse', 'isWarehousePickup',
#        'enableShipToHome', 'isBusinessWarehouse'],
#       dtype='object')

# %% [markdown]
# # How many store has a Gas Department

# %%
df_CA['hasGasDepartment'].value_counts()
# Out:
# True     65
# False    34
# Name: hasGasDepartment, dtype: int64

# %% [markdown]
# # View dataframe of the stores that has gas department along with the gasStationHours and the gasPrices

# %%
df_CA_has_GasDepartment = df_CA[df_CA["hasGasDepartment"] == True]

df_CA_has_GasDepartment[['hasGasDepartment','gasStationHours','gasPrices']]
# Out:
#      hasGasDepartment                                    gasStationHours  \
# 72               True  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 73               True  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 74               True  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 76               True  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 77               True  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# ..                ...                                                ...
# 672              True  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 683              True  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 693              True  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 703              True  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
# 706              True  [{'title': 'Mon-Fri.', 'code': 'open', 'time':...
#
#                                              gasPrices
# 72   {'warehouseid': '152', 'regular': '.909', 'pre...
# 73   {'warehouseid': '153', 'regular': '.909', 'pre...
# 74   {'warehouseid': '154', 'regular': '.909', 'pre...
# 76   {'warehouseid': '156', 'regular': '.909', 'pre...
# 77   {'warehouseid': '158', 'diesel': '.019', 'regu...
# ..                                                 ...
# 672  {'warehouseid': '1273', 'regular': '.869', 'pr...
# 683  {'warehouseid': '1296', 'regular': '.909', 'pr...
# 693  {'warehouseid': '1324', 'regular': '.019', 'pr...
# 703  {'warehouseid': '1345', 'regular': '.909', 'pr...
# 706  {'warehouseid': '1359', 'diesel': '.019', 'reg...
#
# [65 rows x 3 columns]

# %% [markdown]
# # View location of Canada Costco stores, only the ones that has gas stations

# %%
#!pip install streamlit-folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting streamlit-folium
#   Downloading streamlit_folium-0.11.1-py3-none-any.whl (423 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.4/423.4 KB 11.1 MB/s eta 0:00:00
# Collecting streamlit>=1.13.0
#   Downloading streamlit-1.20.0-py2.py3-none-any.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 72.3 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from streamlit-folium) (3.1.2)
# Requirement already satisfied: folium>=0.13 in /usr/local/lib/python3.9/dist-packages (from streamlit-folium) (0.14.0)
# Requirement already satisfied: branca in /usr/local/lib/python3.9/dist-packages (from streamlit-folium) (0.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from folium>=0.13->streamlit-folium) (2.27.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from folium>=0.13->streamlit-folium) (1.22.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->streamlit-folium) (2.1.2)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (4.3)
# Collecting semver
#   Downloading semver-3.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (6.2)
# Requirement already satisfied: pandas<2,>=0.25 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (1.4.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (8.1.3)
# Requirement already satisfied: packaging>=14.1 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (23.0)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (4.2.2)
# Collecting watchdog
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 7.7 MB/s eta 0:00:00
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 67.5 MB/s eta 0:00:00
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (8.4.0)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.6-py3-none-any.whl (13 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (0.10.2)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (13.3.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (5.3.0)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (4.5.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (6.1.0)
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit>=1.13.0->streamlit-folium) (9.0.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit>=1.13.0->streamlit-folium) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit>=1.13.0->streamlit-folium) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit>=1.13.0->streamlit-folium) (4.3.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=1.4->streamlit>=1.13.0->streamlit-folium) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<2,>=0.25->streamlit>=1.13.0->streamlit-folium) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil->streamlit>=1.13.0->streamlit-folium) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->folium>=0.13->streamlit-folium) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->folium>=0.13->streamlit-folium) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->folium>=0.13->streamlit-folium) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->folium>=0.13->streamlit-folium) (1.26.15)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit>=1.13.0->streamlit-folium) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit>=1.13.0->streamlit-folium) (2.2.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal>=1.1->streamlit>=1.13.0->streamlit-folium) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from validators>=0.2->streamlit>=1.13.0->streamlit-folium) (4.4.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit>=1.13.0->streamlit-folium) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit>=1.13.0->streamlit-folium) (22.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit>=1.13.0->streamlit-folium) (0.1.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit>=1.13.0->streamlit-folium) (2022.7)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=5560b6e7407586b6d2f9e5a7d3f5a1f90bb3fffc0bbf38296086eb22d43896ed
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: watchdog, validators, smmap, semver, pympler, blinker, pydeck, gitdb, gitpython, streamlit, streamlit-folium
# Successfully installed blinker-1.6 gitdb-4.0.10 gitpython-3.1.31 pydeck-0.8.0 pympler-1.0.1 semver-3.0.0 smmap-5.0.0 streamlit-1.20.0 streamlit-folium-0.11.1 validators-0.20.0 watchdog-3.0.0

# %%
import folium

df_CA_has_GasDepartment_forMap = df_CA_has_GasDepartment[["latitude", "longitude", "locationName"]]
map = folium.Map(
    location=[
    df_CA_has_GasDepartment_forMap.latitude.mean(), 
    df_CA_has_GasDepartment_forMap.longitude.mean()], zoom_start=5, control_scale=True)

for index, location_info in df_CA_has_GasDepartment_forMap.iterrows():
    folium.Marker([location_info["latitude"], location_info["longitude"]], popup=location_info["locationName"]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c7930ec9c63a4a88c1b8dcce0b12065 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c7930ec9c63a4a88c1b8dcce0b12065&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c7930ec9c63a4a88c1b8dcce0b12065 = L.map(
#                 &quot;map_7c7930ec9c63a4a88c1b8dcce0b12065&quot;,
#                 {
#                     center: [47.7273076923077, -92.00033846153845],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7c7930ec9c63a4a88c1b8dcce0b12065);
#
#
#
#
#
#             var tile_layer_a0644f61d1552274f96d14bd49a69dd9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7c7930ec9c63a4a88c1b8dcce0b12065);
#
#
#             var marker_ddf9ab55bb2f1c868cc3c929ef0610f8 = L.marker(
#                 [52.194, -106.675],
#                 {}
#             ).addTo(map_7c7930ec9c63a4a88c1b8dcce0b12065);
#
#
#         var popup_08f35f4c6d6861772f8b85d77099b21a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_700091bdb25317ee04d92f5d5c7207f1 = $(`&lt;div id=&quot;html_700091bdb25317ee04d92f5d5c7207f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Saskatoon&lt;/div&gt;`)[0];
#                 popup_08f35f4c6d6861772f8b85d77099b21a.setContent(html_700091bdb25317ee04d92f5d5c7207f1);
#
#
#
#         marker_ddf9ab55bb2f1c868cc3c929ef0610f8.bindPopup(popup_08f35f4c6d6861772f8b85d77099b21a)
#         ;
#
#
#
#
#             var marker_911639f5dac52c2bc33f7133f0fbe8e1 = L.marker(
#                 [49.896, -97.054],
#                 {}
#             ).addTo(map_7c7930ec9c63a4a88c1b8dcce0b12065);
#
#
#         var popup_3f8b37fa31fc6c7ff05924b610918dae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f514c45860173d291fcc5faaf185133 = $(`&lt;div id=&quot;html_0f514c45860173d291fcc5faaf185133&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;E Winnipeg&lt;/div&gt;`)[0];
#                 popup_3f8b37fa31fc6c7ff05924b610918dae.setContent(html_0f514c45860173d291fcc5faaf185133);
#
#
#
#         marker_911639f5dac52c2bc33f7133f0fbe8e1.bindPopup(popup_3f8b37fa31fc6c7ff05924b610918dae)
#         ;
#
#
#
#
#             var marker_6a6514c03eb486f53b0a525e82cfb566 = L.marker(
#                 [53.58, -113.58],
#                 {}
#             ).addTo(map_7c7930ec9c63a4a88c1b8dcce0b12065);
#
#
#         var popup_9a6929d86f8c6b9d496183f9acd014c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e71dd032a436f5c6119d5efd643afef5 = $(`&lt;div id=&quot;html_e71dd032a436f5c6119d5efd643afef5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;N Edmonton&lt;/div&gt;`)[0];
#                 popup_9a6929d86f8c6b9d496183f9acd014c4.setContent(html_e71dd032a436f5c6119d5efd643afef5);
#
#
#
#         marker_6a6514c03eb486f53b0a525e82cfb566.bindPopup(popup_9a6929d86f8c6b9d496183f9acd014c4)
#         ;
#
#
#
#
#             var marker_20055c72034ffdf965b32286c66c1d33 = L.marker(
#                 [53.596, -113.415],
#                 {}
#             ).addTo(map_7c7930ec9c63a4a88c1b8dcce0b12065);
#
#
#         var popup_39cff81dabfcd32ae50fe3127695aad0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_867af8e6c52a1a03e371a60770096fd1 = $(`&lt;div id=&quot;html_867af8e6c52a1a03e371a60770096fd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;E Edmonton&lt;/div&gt;`)[0];
#                 popup_39cff81dabfcd32ae50fe3127695aad0.setContent(html_867af8e6c52a1a03e371a60770096fd1);
#
#
#
#         marker_20055c72034ffdf965b32286c66c1d33.bindPopup(popup_39cff81dabfcd32ae50fe3127695aad0)
#         ;
#
#
#
#
#             var marker_d5410e3c9561c64d74d11cd895cac187 = L.marker(
#                 [53.885, -122.771],
#                 {}
#             ).addTo(map_7c7930ec9c63a4a88c1b8dcce0b12065);
#
#
#         var popup_0e16de36195bb3b6924217e6321f9a2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89be9328064174107139a7a17490911b = $(`&lt;div id=&quot;html_89be9328064174107139a7a17490911b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Prince George&lt;/div&gt;`)[0];
#                 popup_0e16de36195bb3b6924217e6321f9a2e.setContent(html_89be9328064174107139a7a17490911b);
#
#
#
#         marker_d5410e3c9561c64d74d11cd895cac187.bindPopup(popup_0e16de36195bb3b6924217e6321f9a2e)
#         ;
#
#
#
#
#             var marker_a4985fb00a983498eb9ca7994c3c3125 = L.marker(

# %%
import streamlit as st
from streamlit_folium import st_folium
import folium

df_CA_has_GasDepartment_forMap = df_CA_has_GasDepartment[["latitude", "longitude", "locationName"]]
map = folium.Map(
    location=[
    df_CA_has_GasDepartment_forMap.latitude.mean(), 
    df_CA_has_GasDepartment_forMap.longitude.mean()], zoom_start=5, control_scale=True)

for index, location_info in df_CA_has_GasDepartment_forMap.iterrows():
    folium.Marker([location_info["latitude"], location_info["longitude"]], popup=location_info["locationName"],tooltip = "Tool Tip").add_to(map)

st_data = st_folium(map , width = 725)
# Out:
# WARNING:root:
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.9/dist-packages/ipykernel_launcher.py [ARGUMENTS]
# 2023-04-04 13:28:21.151
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.9/dist-packages/ipykernel_launcher.py [ARGUMENTS]
